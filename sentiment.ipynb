# %% [markdown]
# # Análise de Sentimentos

# %% [markdown]
# Este é um projeto Python de processamento de linguagem natural criando um classificador de análise de sentimentos com VADER do NLTK e Huggingface Roberta Transformers. O projeto tem objetivo de classificar o sentimento das avaliações de clientes da Amazon.

# %% [markdown]
# ## 1) Lendo os Dados e Noções Básicas de NLTK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# Lendo os dados
df = pd.read_csv('Reviews.csv')
print(df.shape)
# Vamos observar um dataset muito grande, com mais de 500 mil dados, então para simplificar vamos reduzir bastante
df = df.head(500)
print(df.shape)
# Out:
# (568454, 10)
# (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# Vamos fazer uma análise rápida dos nossos dados em seguida:

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# Podemos então usar o básico de NLTK

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# ## 2) VADER Sentiment Scoring

# %% [markdown]
# Vamos utilizar o SentimentIntensityAnalyzer do NLTK para obter os scores do texto (neg-neu-pos).
#
# Para isso, utiliza-se uma abordagem de "Saco de Palavras" em que palavras de parada são removidas e cada palavra é pontuada e combinada para uma pontuação total.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %% [markdown]
# Podemos ver como esse objeto funciona abaixo:

# %%
sia.polarity_scores('i am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
example
# Out:
# "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go."

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %% [markdown]
# Agora vamos rodar o Polarity Score no dataset inteiro:

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
# Armazenando isso em um dataframe
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# Agora vamos plotar os resultados

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3) Modelo Roberta

# %% [markdown]
# Usaremos um modelo treinado de um grande corpus de dados. O modelo Transformer leva em conta as palavras, mas também o contexto relacionado a outras palavras.

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Downloading:   0%|          | 0.00/747 [00:00<?, ?B/s]
# C:\Users\vitor\anaconda3\lib\site-packages\huggingface_hub\file_download.py:127: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\vitor\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# ...

# %%
# Resultados do Vader no nosso exemplo
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Usando agora o modelo Roberta
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.9763551, 'roberta_neu': 0.020687463, 'roberta_pos': 0.0029573687}

# %% [markdown]
# Podemos observar que o Modelo Roberta conseguiu perceber muito mais eficientemente que é um comentário negativo

# %%
# Criando uma função que retorna o dicionario com os scores
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %% [markdown]
# Vamos aplicar para todo nosso dataset:

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items(): # Esse laço é só para alterar o nome da coluna do vader
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %%
results_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098067     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# ...

# %% [markdown]
# # 4) Comparando os Scores dos Modelos

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %% [markdown]
# # 5) Avaliando Exemplos

# %%
# Aqui pegamos um exemplo com 1 estrela de avaliação, mas com o score de positividade mais alto entre os com 1 estrela
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %%
# Aqui vamos tentar analisar exemplos com 5 estrelas de avaliação mas tiveram o score mais baixo
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [markdown]
# # 6) Transformers Pipeline

# %% [markdown]
# Uma forma rápida e fácil de rodar prediçoes de sentimento

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
sent_pipeline('I love sentiment analysis!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997853636741638}]

# %%
sent_pipeline('Make sure to like and subscribe!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9991742968559265}]

# %%
sent_pipeline('booo')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9936267137527466}]

# %% [markdown]
# # FIM
